# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../02_Data/Processed/sp500_features_step1.csv", parse_dates=["date"])

plt.figure(figsize=(12,5))
plt.plot(df["date"], df["log_return"])
plt.title("Daily Log Returns")
plt.grid(True)
plt.show()

print(df["return"].describe())
print(df["log_return"].describe())
# Out:
# count    1486.000000
# mean        0.000585
# std         0.013260
# min        -0.119841
# 25%        -0.004967
# 50%         0.000945
# 75%         0.006965
# max         0.095154
# Name: return, dtype: float64
# count    1487.000000
# mean        0.000496
# std         0.013294
# min        -0.127652
# 25%        -0.004977
# 50%         0.000920
# 75%         0.006930
# max         0.090895
# Name: log_return, dtype: float64
