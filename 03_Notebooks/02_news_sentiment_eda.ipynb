# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../02_Data/Processed/news_sentiment_recent.csv")

plt.hist(df['compound'], bins=30, edgecolor='black')
plt.title("Distribution of News Sentiment (Recent Data)")
plt.xlabel("Compound Sentiment")
plt.ylabel("Frequency")
plt.show()
